# %% [markdown]
# # VII. Types, type hierarchy, and multiple dispatch

# %% [markdown]
# In Julia types play a central role. We've covered enough so far that you can write Julia code as you would in other languages, but having an understanding of types will give you a better understanding of how Julia works and hopefully help you write better Julia code.

# %% [markdown]
# In Julia, everything has a type. As we've already seen, you can figure out an object's type using the __typeof__ funciton.

# %%
typeof( 1.3 )
# Out:
# Float64

# %%
typeof( 22 )
# Out:
# Int64

# %%
typeof( "julia" )
# Out:
# String

# %%
typeof( 3//2 )
# Out:
# Rational{Int64}

# %%
typeof( 3 + 2im )
# Out:
# Complex{Int64}

# %%
typeof( randn( 5, 5 ) )
# Out:
# Array{Float64,2}

# %% [markdown]
# The curly braces indicate the type is a **parametric** type. So *Array* is a parametric type since it's a type with type parameters (in this case *Float64* and *2*).
#
# You can use the __eltype__ function to determine the element type.

# %%
A = rand( 5, 5 )
# Out:
# 5×5 Array{Float64,2}:
#  0.340621  0.560391  0.723921  0.517655   0.518386
#  0.49682   0.74783   0.373878  0.94408    0.515213
#  0.542565  0.226895  0.584024  0.0248887  0.0199738
#  0.308699  0.88129   0.781702  0.416065   0.0999678
#  0.427554  0.74992   0.436451  0.538462   0.17086

# %%
eltype( A )
# Out:
# Float64

# %%
t = ( "summer", 32, 4.3 )
# Out:
# ("summer", 32, 4.3)

# %%
typeof( t )
# Out:
# Tuple{String,Int64,Float64}

# %%
eltype( t )
# Out:
# Any

# %% [markdown]
# Because of Julia's emphasis on types you can sometimes run into unexpected problems. Let's generate a random array of integers between 1 and 20:

# %%
A = rand( 1 : 20, 5, 5 )
# Out:
# 5×5 Array{Int64,2}:
#  11   7   9  14  19
#   1  18  12  20  20
#  14  15  20  12  19
#   5  16   9   4  20
#   2   9   6  18  16

# %% [markdown]
# As stated before, arrays are mutable:

# %%
A[ 1, 1 ] = 19
# Out:
# 19

# %%
A
# Out:
# 5×5 Array{Int64,2}:
#  19   7   9  14  19
#   1  18  12  20  20
#  14  15  20  12  19
#   5  16   9   4  20
#   2   9   6  18  16

# %% [markdown]
# Let's now set element A[1,2] equal to 3.2:

# %%
A[ 1, 2 ] = 3.2
# Out:
# InexactError: Int64(3.2)
#
# Stacktrace:
#  [1] Int64 at ./float.jl:709 [inlined]
#  [2] convert at ./number.jl:7 [inlined]
#  [3] setindex!(::Array{Int64,2}, ::Float64, ::Int64, ::Int64) at ./array.jl:784
#  [4] top-level scope at In[15]:1

# %% [markdown]
# What happened here?

# %% [markdown]
# ### How types are organized in Julia:

# %% [markdown]
# In Julia, types are organized according according to a tree like  structure. At the top of the tree is the *Any* type. So all types are subtypes of *Any*. At the bottom of the tree (the leaves of the tree) are __concrete types__, i.e. Float64, Int64, UInt32, etc. A type can have at most one parent, but possibly more than one child.

# %% [markdown]
# To get a sense of how the type hierarchy is organized you can use the functions __subtypes__ and __supertype__. Let's start with a simple concrete type *Float64* and traverse the tree upwards.

# %%
supertype( Float64 )
# Out:
# AbstractFloat

# %% [markdown]
# So the parent of *Float64* is a type called *AbstractFloat* which in Julia is called an **abstract type**.

# %%
supertype( AbstractFloat )
# Out:
# Real

# %%
supertype( Real )
# Out:
# Number

# %%
supertype( Number )
# Out:
# Any

# %%
supertype( Any )
# Out:
# Any

# %% [markdown]
# From the above ouptut, we see that *Real*, *Number*, etc. are also **abstract types** (i.e. they can have children). When you create variables in Julia they can only be __concrete types__, i.e. you can not instantiate a variable of type *Real*.

# %% [markdown]
# Let's now start with the *Real* type and use the **subtypes** function to go down the tree.

# %%
subtypes( Real )
# Out:
# 4-element Array{Any,1}:
#  AbstractFloat
#  AbstractIrrational
#  Integer
#  Rational

# %% [markdown]
# So *Real* has four subtypes: *AbstractFloat*, *Integer*, *Irrational*, *Rational*.

# %%
subtypes( Integer )
# Out:
# 3-element Array{Any,1}:
#  Bool
#  Signed
#  Unsigned

# %%
subtypes( Signed )
# Out:
# 6-element Array{Any,1}:
#  BigInt
#  Int128
#  Int16
#  Int32
#  Int64
#  Int8

# %%
subtypes( Int64 )
# Out:
# 0-element Array{Type,1}

# %% [markdown]
# We can see that *Int64* is a **concrete type**. There are also suptype and supertype operators you can use to ask questions if a type is a supertype or subtype of some other type. Here we test if *Real* is a subtype of *Number*:

# %%
Real <: Number
# Out:
# true

# %% [markdown]
# Is *Int64* a subtype of *Float64*?

# %%
Int64 <: Float64
# Out:
# false

# %% [markdown]
# Let's test if *Real* is a supertype of *Rational*:

# %%
Real >: Rational
# Out:
# true

# %% [markdown]
# Is *Int64* a supertype of *Complex*?

# %%
Int64 >: Complex
# Out:
# false

# %% [markdown]
# Types are important in Julia for many reasons, but perhaps most obviously due to Julia's approach to calling functions known as **multiple dispatch**.

# %% [markdown]
# In Julia many versions of the same named function can exist and these different versions are called **methods**. The methods differ in that they have different function signatures. In general, these different methods correspond to a specific type of behavior by the function determined by the type of inputs.

# %% [markdown]
# You can see this with the built-in multiplication function __*__:

# %%
*( 3, 2.2 )
# Out:
# 6.6000000000000005

# %%
*( "string","input" )
# Out:
# "stringinput"

# %% [markdown]
# As we can see the behavior of __*__ is different depending on the input types: for numbers it does multiplication and for strings it does concatenation. You can see all the methods for a function using **methods**:

# %%
methods( * )
# Out:
# # 358 methods for generic function "*":
# [1] *(x::Bool, z::Complex{Bool}) in Base at complex.jl:286
# [2] *(x::Bool, y::Bool) in Base at bool.jl:98
# [3] *(x::Bool, y::T) where T<:AbstractFloat in Base at bool.jl:110
# [4] *(x::Bool, z::Complex) in Base at complex.jl:293
# [5] *(x::Bool, y::AbstractIrrational) in Base at irrationals.jl:139
# [6] *(a::Float16, b::Float16) in Base at float.jl:398
# [7] *(x::Float32, y::Float32) in Base at float.jl:404
# [8] *(x::Float64, y::Float64) in Base at float.jl:405
# [9] *(z::Complex{Bool}, x::Bool) in Base at complex.jl:287
# [10] *(z::Complex{Bool}, x::Real) in Base at complex.jl:305
# [11] *(r::Regex) in Base at regex.jl:660
# [12] *(::Missing, ::Missing) in Base at missing.jl:114
# [13] *(::Missing, ::Number) in Base at missing.jl:115
# [14] *(d::Missing, x::AbstractString) in Base at missing.jl:170
# [15] *(this::Base.Grisu.Float, other::Base.Grisu.Float) in Base.Grisu at grisu/float.jl:140
# [16] *(c::BigInt, x::BigFloat) in Base.MPFR at mpfr.jl:413
# [17] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt, e::BigInt) in Base.GMP at gmp.jl:503
# [18] *(a::BigInt, b::BigInt, c::BigInt, d::BigInt) in Base.GMP at gmp.jl:502
# [19] *(a::BigInt, b::BigInt, c::BigInt) in Base.GMP at gmp.jl:501
# [20] *(x::BigInt, y::BigInt) in Base.GMP at gmp.jl:472
# [21] *(x::BigInt, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.GMP at gmp.jl:520
# [22] *(x::BigInt, c::Union{Int16, Int32, Int64, Int8}) in Base.GMP at gmp.jl:522
# [23] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat, e::BigFloat) in Base.MPFR at mpfr.jl:563
# [24] *(a::BigFloat, b::BigFloat, c::BigFloat, d::BigFloat) in Base.MPFR at mpfr.jl:556
# [25] *(a::BigFloat, b::BigFloat, c::BigFloat) in Base.MPFR at mpfr.jl:550
# [26] *(x::BigFloat, c::BigInt) in Base.MPFR at mpfr.jl:409
# [27] *(x::BigFloat, y::BigFloat) in Base.MPFR at mpfr.jl:378
# [28] *(x::BigFloat, c::Union{UInt16, UInt32, UInt64, UInt8}) in Base.MPFR at mpfr.jl:385
# [29] *(x::BigFloat, c::Union{Int16, Int32, Int64, Int8}) in Base.MPFR at mpfr.jl:393
# [30] *(x::BigFloat, c::Union{Float16, Float32, Float64}) in Base.MPFR at mpfr.jl:401
# [31] *(B::BitArray{2}, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:195
# [32] *(y::AbstractFloat, x::Bool) in Base at bool.jl:112
# [33] *(x::T, y::T) where T<:Union{Int128, UInt128} in Base at int.jl:859
# [34] *(x::T, y::T) where T<:Union{Int128, Int16, Int32, Int64, Int8, UInt128, UInt16, UInt32, UInt64, UInt8} in Base at int.jl:54
# [35] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigInt) in Base.GMP at gmp.jl:521
# [36] *(c::Union{Int16, Int32, Int64, Int8}, x::BigInt) in Base.GMP at gmp.jl:523
# [37] *(a::Integer, b::Integer) in Base at int.jl:871
# [38] *(x::Real, r::StepRangeLen{#s66,#s65,S} where S where #s65<:Base.TwicePrecision where #s66<:Real) in Base at twiceprecision.jl:479
# [39] *(z::Complex, w::Complex) in Base at complex.jl:273
# [40] *(z::Complex, x::Bool) in Base at complex.jl:294
# [41] *(x::Real, z::Complex{Bool}) in Base at complex.jl:304
# [42] *(x::Real, z::Complex) in Base at complex.jl:316
# [43] *(z::Complex, x::Real) in Base at complex.jl:317
# [44] *(x::Rational, y::Rational) in Base at rational.jl:264
# [45] *(a::Integer, index::CartesianIndex{N}) where N in Base.IteratorsMD at multidimensional.jl:119
# [46] *(c::Union{UInt16, UInt32, UInt64, UInt8}, x::BigFloat) in Base.MPFR at mpfr.jl:389
# [47] *(c::Union{Int16, Int32, Int64, Int8}, x::BigFloat) in Base.MPFR at mpfr.jl:397
# [48] *(c::Union{Float16, Float32, Float64}, x::BigFloat) in Base.MPFR at mpfr.jl:405
# [49] *(x::AbstractIrrational, y::AbstractIrrational) in Base at irrationals.jl:137
# [50] *(y::Real, x::Dates.Period) in Dates at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/Dates/src/periods.jl:93
# [51] *(x::Real, A::LinearAlgebra.Hermitian) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:494
# [52] *(x::Number) in Base at operators.jl:505
# [53] *(x::T, y::T) where T<:Number in Base at promotion.jl:388
# [54] *(x::Number, y::Number) in Base at promotion.jl:312
# [55] *(x::Base.TwicePrecision{#s66} where #s66<:Union{Float16, Float32, Float64}, v::Integer) in Base at twiceprecision.jl:286
# [56] *(x::Base.TwicePrecision, v::Number) in Base at twiceprecision.jl:282
# [57] *(v::Number, x::Base.TwicePrecision) in Base at twiceprecision.jl:291
# [58] *(x::Base.TwicePrecision{T}, y::Base.TwicePrecision{T}) where T in Base at twiceprecision.jl:294
# [59] *(x::Base.TwicePrecision, y::Base.TwicePrecision) in Base at twiceprecision.jl:298
# [60] *(r::StepRangeLen{#s66,#s65,S} where S where #s65<:Base.TwicePrecision where #s66<:Real, x::Real) in Base at twiceprecision.jl:481
# [61] *(X::Union{DenseArray{P,N}, Base.ReinterpretArray{P,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{P,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{P,N,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where N, y::Real) where P<:Dates.Period in Dates at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/Dates/src/deprecated.jl:46
# [62] *(u::LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(LinearAlgebra.Transpose{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T) where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/adjtrans.jl:263
# [63] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.AbstractTriangular where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2039
# [64] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.AbstractTriangular where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:926
# [65] *(v::LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T, A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2026
# [66] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:922
# [67] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(AbstractArray{T,1} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2556
# [68] *(adjQ::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractQ where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/qr.jl:630
# [69] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s627, adjQ::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.AbstractQ where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/qr.jl:733
# [70] *(u::LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T, A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractQ where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/qr.jl:721
# [71] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.LQPackedQ where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{DenseArray{T,1}, DenseArray{T,2}, Base.ReinterpretArray{T,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/lq.jl:218
# [72] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where T) where #s627, adjQ::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.LQPackedQ where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/lq.jl:255
# [73] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:477
# [74] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:479
# [75] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:481
# [76] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:478
# [77] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:480
# [78] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:482
# [79] *(adjD::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.Diagonal where #s627, adjA::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/diagonal.jl:367
# [80] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(AbstractArray{T,1} where T) where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:903
# [81] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, adjD::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.Diagonal where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/diagonal.jl:366
# [82] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(AbstractArray{T,1} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:912
# [83] *(D::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.Diagonal where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.Diagonal where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/diagonal.jl:253
# [84] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:SparseArrays.SparseMatrixCSC{Tv,Ti} where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:SparseArrays.SparseMatrixCSC{Tv,Ti} where #s625) where {Tv, Ti} in SparseArrays at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/linalg.jl:192
# [85] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:SparseArrays.SparseMatrixCSC{TvA,TiA} where #s627, adjB::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:SparseArrays.SparseMatrixCSC{TvB,TiB} where #s625) where {TvA, TiA, TvB, TiB} in SparseArrays at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/linalg.jl:20
# [86] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:SparseArrays.SparseMatrixCSC{TA,S} where #s627, B::Union{DenseArray{Tx,2}, Base.ReinterpretArray{Tx,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{Tx,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{Tx,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s627,#s626} where #s626<:Union{DenseArray{Tx,2}, Base.ReinterpretArray{Tx,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{Tx,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{Tx,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where #s627, LinearAlgebra.Transpose{#s625,#s624} where #s624<:Union{DenseArray{Tx,2}, Base.ReinterpretArray{Tx,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{Tx,2,A,MI} where M ...
# [87] *(X::Union{DenseArray{TX,2}, Base.ReinterpretArray{TX,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TX,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{TX,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, LinearAlgebra.Adjoint{#s627,#s626} where #s626<:Union{DenseArray{TX,2}, Base.ReinterpretArray{TX,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TX,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{TX,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where #s627, LinearAlgebra.Transpose{#s625,#s624} where #s624<:Union{DenseArray{TX,2}, Base.ReinterpretArray{TX,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TX,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Un ...
# [88] *(u::LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/adjtrans.jl:256
# [89] *(u::LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T, v::LinearAlgebra.Transpose{#s627,#s626} where #s626<:(LinearAlgebra.Adjoint{T,#s627} where #s627<:(AbstractArray{T,1} where T) where T) where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/adjtrans.jl:267
# [90] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:Union{DenseArray{T,2}, Base.ReinterpretArray{T,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{T,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{T,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}} where #s627, x::Union{DenseArray{S,1}, Base.ReinterpretArray{S,1,S1,A} where S1 where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{S,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{S,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}}) where {T<:Union{Complex{Float32}, Complex{Float64}, Float32, Float64}, S} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/matmul.jl:106
# [91] *(xformA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.UpperTriangular where #s627, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:1719
# [92] *(xformA::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.UnitUpperTriangular where #s625, B::LinearAlgebra.LowerTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:1728
# [93] *(xformA::LinearAlgebra.Adjoint{#s623,#s622} where #s622<:LinearAlgebra.LowerTriangular where #s623, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:1737
# [94] *(xformA::LinearAlgebra.Adjoint{#s621,#s620} where #s620<:LinearAlgebra.UnitLowerTriangular where #s621, B::LinearAlgebra.UpperTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:1746
# [95] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:1837
# [96] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:(AbstractArray{T,2} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2040
# [97] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Transpose{#s625,#s624} where #s624<:LinearAlgebra.AbstractTriangular where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2553
# [98] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Transpose{#s625,#s624} where #s624<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:923
# [99] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Transpose{#s625,#s624} where #s624<:(AbstractArray{T,2} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2557
# [100] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Transpose{#s625,#s624} where #s624<:(AbstractArray{T,1} where T) where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2558
# [101] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, D::LinearAlgebra.Diagonal) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/diagonal.jl:217
# [102] *(A::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::LinearAlgebra.Adjoint{#s625,#s624} where #s624<:LinearAlgebra.AbstractRotation where #s625) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/givens.jl:394
# [103] *(L::Union{LinearAlgebra.Adjoint{T,#s627} where #s627<:(LinearAlgebra.UpperTriangular{T,#s626} where #s626<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.Adjoint{T,#s625} where #s625<:(LinearAlgebra.UnitUpperTriangular{T,#s624} where #s624<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.Adjoint{T,#s627} where #s627<:(LinearAlgebra.LowerTriangular{T,#s626} where #s626<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.Adjoint{T,#s625} where #s625<:(LinearAlgebra.UnitLowerTriangular{T,#s624} where #s624<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.LowerTriangular{T,#s627} where #s627<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti), LinearAlgebra.Transpose{T,#s623} where #s623<:(LinearAlgebra.UpperTriangular{T,#s622} where #s622<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.Transpose{T,#s621} where #s621<:(LinearAlgebra.UnitUpperTriangular{T,#s620} where #s620<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.Transpose{T,#s623} where #s623<:(LinearAlgebra.LowerTriangular{T,#s622} where #s622<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.Transpose{T,#s621} where #s621<:(LinearAlgebra.UnitLowerTriangular{T,#s620} where #s620<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)), LinearAlgebra.UnitLowerTriangular{T,#s626} where #s626<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti), LinearAlgebra.UnitUpperTriangular{T,#s626} where #s626<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti), LinearAlgebra.UpperTriangular{T,#s627} where #s627<:(Union{SparseArrays.SparseMatrixCSC{T,Ti}, SubArray{T,2,SparseArrays.SparseMatrixCSC{T,Ti},Tuple{Base.Slice{Base.OneTo{Int64}},I},L} where L where I<:AbstractUnitRange} where Ti)} where T, B::SparseArrays.SparseMatrixCSC) in SparseArrays at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/linalg.jl:721
# [104] *(adjA::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627, B::AbstractArray{T,1} where T) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:1877
# ...
# [301] *(A::SparseArrays.SparseMatrixCSC, D::LinearAlgebra.Diagonal) in SparseArrays at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/linalg.jl:180
# [302] *(A::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}, B::Union{LinearAlgebra.Bidiagonal, LinearAlgebra.SymTridiagonal, LinearAlgebra.Tridiagonal}) in SparseArrays at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/SparseArrays.jl:57
# [303] *(A::SuiteSparse.CHOLMOD.Sparse, B::SuiteSparse.CHOLMOD.Sparse) in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1210
# [304] *(A::SuiteSparse.CHOLMOD.Sparse, B::SuiteSparse.CHOLMOD.Dense) in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1211
# [305] *(A::SuiteSparse.CHOLMOD.Sparse, B::Union{Array{T,1}, Array{T,2}} where T) in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1212
# [306] *(A::SuiteSparse.CHOLMOD.Sparse{Tv}, adjB::LinearAlgebra.Adjoint{Tv,SuiteSparse.CHOLMOD.Sparse{Tv}}) where Tv<:Float64 in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1215
# [307] *(A::LinearAlgebra.Symmetric{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1826
# [308] *(A::LinearAlgebra.Hermitian{Complex{Float64},SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}, SparseArrays.SparseVector{Complex{Float64},Ti}}) where Ti in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1828
# [309] *(A::LinearAlgebra.Hermitian{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}, B::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1830
# [310] *(A::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}, B::LinearAlgebra.Symmetric{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1833
# [311] *(A::Union{SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}, SparseArrays.SparseVector{Complex{Float64},Ti}}, B::LinearAlgebra.Hermitian{Complex{Float64},SparseArrays.SparseMatrixCSC{Complex{Float64},Ti}}) where Ti in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1835
# [312] *(A::Union{SparseArrays.SparseMatrixCSC{Float64,Ti}, SparseArrays.SparseVector{Float64,Ti}}, B::LinearAlgebra.Hermitian{Float64,SparseArrays.SparseMatrixCSC{Float64,Ti}}) where Ti in SuiteSparse.CHOLMOD at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SuiteSparse/src/cholmod.jl:1837
# [313] *(x::AbstractArray{#s66,2} where #s66<:Number) in Base at abstractarraymath.jl:98
# [314] *(B::Number, A::LinearAlgebra.SymTridiagonal) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/tridiag.jl:161
# [315] *(B::Number, A::LinearAlgebra.Tridiagonal) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/tridiag.jl:639
# [316] *(x::Number, A::LinearAlgebra.UpperTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:753
# [317] *(x::Number, A::LinearAlgebra.UnitUpperTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:756
# [318] *(x::Number, A::LinearAlgebra.LowerTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:753
# [319] *(x::Number, A::LinearAlgebra.UnitLowerTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:756
# [320] *(x::Number, A::LinearAlgebra.Symmetric) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:492
# [321] *(x::Number, D::LinearAlgebra.Diagonal) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/diagonal.jl:159
# [322] *(B::Number, A::LinearAlgebra.Bidiagonal) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/bidiag.jl:328
# [323] *(a::Number, x::Union{SubArray{T,1,#s627,Tuple{Base.Slice{Base.OneTo{Int64}},Int64},false} where #s627<:SparseArrays.SparseMatrixCSC, SparseArrays.SparseVector{T,Ti} where Ti<:Integer} where T) in SparseArrays at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/SparseArrays/src/sparsevector.jl:1408
# [324] *(A::Number, B::AbstractArray) in Base at arraymath.jl:52
# [325] *(A::AbstractArray, B::Number) in Base at arraymath.jl:55
# [326] *(s1::Union{AbstractChar, AbstractString}, ss::Union{AbstractChar, AbstractString}...) in Base at strings/basic.jl:230
# [327] *(r1::Union{Regex, AbstractChar, AbstractString}, rs::Union{Regex, AbstractChar, AbstractString}...) in Base at regex.jl:640
# [328] *(index::CartesianIndex, a::Integer) in Base.IteratorsMD at multidimensional.jl:120
# [329] *(::Number, ::Missing) in Base at missing.jl:116
# [330] *(d::AbstractString, x::Missing) in Base at missing.jl:171
# [331] *(x::P, y::Real) where P<:Dates.Period in Dates at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/Dates/src/periods.jl:92
# [332] *(u::AbstractArray{T,1} where T, v::Union{LinearAlgebra.Adjoint{T,#s627}, LinearAlgebra.Transpose{T,#s627}} where #s627<:(AbstractArray{T,1} where T) where T) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/adjtrans.jl:253
# [333] *(A::AbstractArray{T,2} where T, B::LinearAlgebra.AbstractTriangular) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2001
# [334] *(A::AbstractArray{T,2} where T, adjB::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2008
# [335] *(A::AbstractArray{T,2} where T, transB::LinearAlgebra.Transpose{#s627,#s626} where #s626<:LinearAlgebra.AbstractTriangular where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/triangular.jl:2016
# [336] *(A::AbstractArray{T,2} where T, transB::LinearAlgebra.Transpose{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Symmetric{T,S}, LinearAlgebra.Symmetric{Complex{T},S}} where S where T<:Real) where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:464
# [337] *(A::AbstractArray{T,2} where T, adjB::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(Union{LinearAlgebra.Hermitian{T,S}, LinearAlgebra.Hermitian{Complex{T},S}, LinearAlgebra.Symmetric{T,S}} where S where T<:Real) where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/symmetric.jl:468
# [338] *(A::AbstractArray{T,2} where T, D::LinearAlgebra.Diagonal) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/diagonal.jl:168
# [339] *(A::AbstractArray{T,2} where T, adjR::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractRotation where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/givens.jl:14
# [340] *(A::AbstractArray{T,2}, x::AbstractArray{S,1}) where {T, S} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/matmul.jl:50
# [341] *(a::AbstractArray{T,1} where T, transB::LinearAlgebra.Transpose{#s627,#s626} where #s626<:(AbstractArray{T,2} where T) where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/matmul.jl:56
# [342] *(a::AbstractArray{T,1} where T, adjB::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:(AbstractArray{T,2} where T) where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/matmul.jl:60
# [343] *(A::AbstractArray{T,1} where T, adjR::LinearAlgebra.Adjoint{#s627,#s626} where #s626<:LinearAlgebra.AbstractRotation where #s627) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/givens.jl:13
# [344] *(a::AbstractArray{T,1} where T, B::AbstractArray{T,2} where T) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/matmul.jl:63
# [345] *(A::AbstractArray{T,2} where T, B::AbstractArray{T,2} where T) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/matmul.jl:152
# [346] *(A::LinearAlgebra.LQ{TA,S} where S<:AbstractArray{TA,2}, B::Union{DenseArray{TB,1}, DenseArray{TB,2}, Base.ReinterpretArray{TB,1,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReinterpretArray{TB,2,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TB,1,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, Base.ReshapedArray{TB,2,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray}, SubArray{TB,1,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}, SubArray{TB,2,A,I,L} where L where I<:Tuple{Vararg{Union{Int64, AbstractRange{Int64}, Base.AbstractCartesianIndex},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, Base.ReshapedArray{T,N,A,MI} where MI<:Tuple{Vararg{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},N} where N} where A<:Union{Base.ReinterpretArray{T,N,S,A} where S where A<:Union{SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, SubArray{T,N,A,I,true} where I<:Union{Tuple{Vararg{Real,N} where N}, Tuple{AbstractUnitRange,Vararg{Any,N} where N}} where A<:DenseArray where N where T, DenseArray} where N where T, DenseArray}}) where {TA, TB} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/lq.jl:179
# [347] *(J1::LinearAlgebra.UniformScaling, J2::LinearAlgebra.UniformScaling) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:194
# [348] *(J::LinearAlgebra.UniformScaling, B::BitArray{2}) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:196
# [349] *(A::AbstractArray{T,2} where T, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:197
# [350] *(J::LinearAlgebra.UniformScaling, A::Union{AbstractArray{T,1}, AbstractArray{T,2}} where T) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:198
# [351] *(x::Number, J::LinearAlgebra.UniformScaling) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:199
# [352] *(J::LinearAlgebra.UniformScaling, x::Number) in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/uniformscaling.jl:200
# [353] *(F::LinearAlgebra.Hessenberg{#s627,#s626,S,W,V} where V<:Number where W<:(AbstractArray{T,1} where T) where S<:(AbstractArray{T,2} where T) where #s626<:AbstractArray{T,2} where #s627, x::S) where {T, S<:Number} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/hessenberg.jl:499
# [354] *(x::S, F::LinearAlgebra.Hessenberg{#s627,#s626,S,W,V} where V<:Number where W<:(AbstractArray{T,1} where T) where S<:(AbstractArray{T,2} where T) where #s626<:AbstractArray{T,2} where #s627) where {T, S<:Number} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/hessenberg.jl:507
# [355] *(R::LinearAlgebra.AbstractRotation{T}, A::Union{AbstractArray{S,1}, AbstractArray{S,2}}) where {T, S} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/givens.jl:10
# [356] *(A::AbstractArray{T,2}, R::LinearAlgebra.AbstractRotation{S}) where {T, S} in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/givens.jl:21
# [357] *(G1::LinearAlgebra.Givens{T}, G2::LinearAlgebra.Givens{T}) where T in LinearAlgebra at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.3/LinearAlgebra/src/givens.jl:383
# [358] *(a, b, c, xs...) in Base at operators.jl:529

# %% [markdown]
# What Julia does at runtime is call the specialized version of the function (i.e. method) that corresponds to the type of input arguments being passed.

# %% [markdown]
# You can incorporate this type of behavior into your own functions. Let's write a function that takes a Float64 squares it, and returns the result.

# %%
function MySquareSpecific( x::Float64 )
    return x^2
end
# Out:
# MySquareSpecific (generic function with 1 method)

# %% [markdown]
# Passing a *Float64* should work, but passing an *Int64* will not:

# %%
MySquareSpecific( 3.2 )
# Out:
# 10.240000000000002

# %%
MySquareSpecific( 2 )
# Out:
# MethodError: no method matching MySquareSpecific(::Int64)
# Closest candidates are:
#   MySquareSpecific(!Matched::Float64) at In[32]:2
#
# Stacktrace:
#  [1] top-level scope at In[34]:1

# %% [markdown]
# To remedy this we could write another method for MySquuareSpecific to work on an Int64.

# %%
function MySquareSpecific( x::Int64 )
    return x^2
end
# Out:
# MySquareSpecific (generic function with 2 methods)

# %% [markdown]
# Our function now has two methods:

# %%
methods( MySquareSpecific )
# Out:
# # 2 methods for generic function "MySquareSpecific":
# [1] MySquareSpecific(x::Int64) in Main at In[35]:2
# [2] MySquareSpecific(x::Float64) in Main at In[32]:2

# %%
round(MySquareSpecific( 3.2 ), digits = 4 )
# Out:
# 10.24

# %%
MySquareSpecific( 2 )
# Out:
# 4

# %% [markdown]
# Though the function will not work on arguments of the Rational type which is something we might want.

# %%
MySquareSpecific( 3//2 )
# Out:
# MethodError: no method matching MySquareSpecific(::Rational{Int64})
# Closest candidates are:
#   MySquareSpecific(!Matched::Int64) at In[35]:2
#   MySquareSpecific(!Matched::Float64) at In[32]:2
#
# Stacktrace:
#  [1] top-level scope at In[39]:1

# %% [markdown]
# Instead of writing multiple versions of our function we could've written a generalized version to work on anything that's a subtype of *Real*.

# %%
function MySquareGen( x :: Real )
    return x .^ 2
end
# Out:
# MySquareGen (generic function with 1 method)

# %%
a, b, c = MySquareGen( 3.2 ), MySquareGen( 2 ), MySquareGen( 3//2 )
# Out:
# (10.240000000000002, 4, 9//4)

# %% [markdown]
# However, in our case the best thing to do would be to leave the input type unspecified and simply do:

# %%
function MySquare(x)
    return x^2
end
# Out:
# MySquare (generic function with 1 method)

# %% [markdown]
# Reason being, Julia will do type inference on the argument being passed in. The first time it encounters this argument type it will infer the argument type, then compile and cache this compiled version of the function for the inferred argument type. The next time the function is called with the same argument type Julia will call the specialized compiled version that it has stored in memory.

# %% [markdown]
# For your reference, if you wanted to define a function whose input was an Array of Float64s that would look something like the following:

# %%
function ArrFloat( A :: Array{ Float64 } )
    #statements
end
# Out:
# ArrFloat (generic function with 1 method)

# %% [markdown]
# And if you wanted to define a function whose input was an Array whose elements are restricted to being subtypes of *Real*:

# %%
function ArrReal( A :: Array{ Real } )
     #statements
end
# Out:
# ArrReal (generic function with 1 method)

# %% [markdown]
# # Exercise 6
# * Find the supertype of the Bool type.
# * Is Int64 subtype of Bool?
# * Display all the methods for the "isless" function.

# %% [markdown]
# In this lesson we covered:
# * Julia types
# * Type operations
# * Mulitple dispatch
